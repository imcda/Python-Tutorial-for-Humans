# %%
import numpy as np
import matplotlib.pyplot as plt

y = ['113.8', '110.9', '109.9', '110.3', '113.1', '107.3', '112.2', '108.9', '106.1', '113.0', '109.0', '107.8', '115.9', '109.6', '112.6', '114.7', '109.4', '115.5', '112.9', '110.4', '112.4', '111.4', '111.4', '111.4', '104.8', '104.5', '108.1', '111.1', '105.9', '107.7']
x = ['105.2', '105.7', '106.5', '107.0', '107.1', '107.6', '107.8', '108.1', '108.8', '108.9', '109.2', '109.5', '109.5', '109.7', '110.0', '110.5', '110.7', '110.7', '111.2', '111.5', '111.5', '112.5', '112.6', '112.9', '113.2', '113.7', '113.9', '113.9', '115.1', '117.6']
plt.figure(figsize=(15,12))
plt.scatter(x,y,marker='x',color='r')
plt.show()
#fig.savefig('a.png') #储存结果

# %%
import numpy as np
import matplotlib.pyplot as plt

y = ['113.8', '110.9', '109.9', '110.3', '113.1', '107.3', '112.2', '108.9', '106.1', '113.0', '109.0', '107.8', '115.9', '109.6', '112.6', '114.7', '109.4', '115.5', '112.9', '110.4', '112.4', '111.4', '111.4', '111.4', '104.8', '104.5', '108.1', '111.1', '105.9', '107.7']
x = ['105.2', '105.7', '106.5', '107.0', '107.1', '107.6', '107.8', '108.1', '108.8', '108.9', '109.2', '109.5', '109.5', '109.7', '110.0', '110.5', '110.7', '110.7', '111.2', '111.5', '111.5', '112.5', '112.6', '112.9', '113.2', '113.7', '113.9', '113.9', '115.1', '117.6']

y = [float(i) for i in y]
x = [float(i) for i in x]

plt.figure(figsize=(20,12))
plt.scatter(x,y,marker='x',color='r')
plt.axis([100, 120, 100, 120])
plt.show()
#fig.savefig('a.png') #储存结果
